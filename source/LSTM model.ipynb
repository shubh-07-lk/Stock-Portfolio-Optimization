# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %%
# !pip install pandas-datareader

# %%
import pandas_datareader as data

# %%
# !pip install yfinance
import yfinance as yf
import pandas as pd

start = '2010-01-01'
end = '2022-12-31'

df = yf.download('AAPL', start=start, end=end)
# Out:
# ...
# [*********************100%***********************]  1 of 1 completed

# %%
df.head()
# Out:
# Price                     Adj Close     Close      High       Low      Open  \
# Ticker                         AAPL      AAPL      AAPL      AAPL      AAPL
# Date
# 2010-01-04 00:00:00+00:00  6.454504  7.643214  7.660714  7.585000  7.622500
# 2010-01-05 00:00:00+00:00  6.465665  7.656429  7.699643  7.616071  7.664286
# 2010-01-06 00:00:00+00:00  6.362819  7.534643  7.686786  7.526786  7.656429
# 2010-01-07 00:00:00+00:00  6.351057  7.520714  7.571429  7.466071  7.562500
# 2010-01-08 00:00:00+00:00  6.393281  7.570714  7.571429  7.466429  7.510714
#
# Price                         Volume
# Ticker                          AAPL
# Date
# 2010-01-04 00:00:00+00:00  493729600
# 2010-01-05 00:00:00+00:00  601904800
# 2010-01-06 00:00:00+00:00  552160000
# 2010-01-07 00:00:00+00:00  477131200
# 2010-01-08 00:00:00+00:00  447610800

# %%
df.tail()
# Out:
# Price                       Adj Close       Close        High         Low  \
# Ticker                           AAPL        AAPL        AAPL        AAPL
# Date
# 2022-12-23 00:00:00+00:00  130.631363  131.860001  132.419998  129.639999
# 2022-12-27 00:00:00+00:00  128.818420  130.029999  131.410004  128.720001
# 2022-12-28 00:00:00+00:00  124.865585  126.040001  131.029999  125.870003
# 2022-12-29 00:00:00+00:00  128.402328  129.610001  130.479996  127.730003
# 2022-12-30 00:00:00+00:00  128.719345  129.929993  129.949997  127.430000
#
# Price                            Open    Volume
# Ticker                           AAPL      AAPL
# Date
# 2022-12-23 00:00:00+00:00  130.919998  63814900
# 2022-12-27 00:00:00+00:00  131.380005  69007800
# 2022-12-28 00:00:00+00:00  129.669998  85438400
# 2022-12-29 00:00:00+00:00  127.989998  75703700
# 2022-12-30 00:00:00+00:00  128.410004  77034200

# %%
df= df.reset_index()
df.head()
# Out:
# Price                       Date Adj Close     Close      High       Low  \
# Ticker                                AAPL      AAPL      AAPL      AAPL
# 0      2010-01-04 00:00:00+00:00  6.454504  7.643214  7.660714  7.585000
# 1      2010-01-05 00:00:00+00:00  6.465665  7.656429  7.699643  7.616071
# 2      2010-01-06 00:00:00+00:00  6.362819  7.534643  7.686786  7.526786
# 3      2010-01-07 00:00:00+00:00  6.351057  7.520714  7.571429  7.466071
# 4      2010-01-08 00:00:00+00:00  6.393281  7.570714  7.571429  7.466429
#
# Price       Open     Volume
# Ticker      AAPL       AAPL
# 0       7.622500  493729600
# 1       7.664286  601904800
# 2       7.656429  552160000
# 3       7.562500  477131200
# 4       7.510714  447610800

# %%
columns_to_drop = ['Date', 'Adj Close']
existing_columns = [col for col in columns_to_drop if col in df.columns]
df = df.drop(existing_columns, axis=1)
df.head()
# Out:
# C:\Users\sujan\AppData\Local\Temp\ipykernel_10724\882231944.py:3: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   df = df.drop(existing_columns, axis=1)
# Price      Close      High       Low      Open     Volume
# Ticker      AAPL      AAPL      AAPL      AAPL       AAPL
# 0       7.643214  7.660714  7.585000  7.622500  493729600
# 1       7.656429  7.699643  7.616071  7.664286  601904800
# 2       7.534643  7.686786  7.526786  7.656429  552160000
# 3       7.520714  7.571429  7.466071  7.562500  477131200
# 4       7.570714  7.571429  7.466429  7.510714  447610800

# %%
plt.plot(df.Close)

# %%
df
# Out:
# Price        Close        High         Low        Open     Volume
# Ticker        AAPL        AAPL        AAPL        AAPL       AAPL
# 0         7.643214    7.660714    7.585000    7.622500  493729600
# 1         7.656429    7.699643    7.616071    7.664286  601904800
# 2         7.534643    7.686786    7.526786    7.656429  552160000
# 3         7.520714    7.571429    7.466071    7.562500  477131200
# 4         7.570714    7.571429    7.466429    7.510714  447610800
# ...            ...         ...         ...         ...        ...
# 3267    131.860001  132.419998  129.639999  130.919998   63814900
# 3268    130.029999  131.410004  128.720001  131.380005   69007800
# 3269    126.040001  131.029999  125.870003  129.669998   85438400
# 3270    129.610001  130.479996  127.730003  127.989998   75703700
# 3271    129.929993  129.949997  127.430000  128.410004   77034200
#
# [3272 rows x 5 columns]

# %%
ma100 = df.Close.rolling(100).mean()
ma100
# Out:
# Ticker        AAPL
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ...            ...
# 3267    150.515600
# 3268    150.157800
# 3269    149.764699
# 3270    149.412100
# 3271    149.062199
#
# [3272 rows x 1 columns]

# %%
plt.figure(figsize = (12,6))
plt.plot(df.Close)
plt.plot(ma100, 'r')

# %%
ma200 = df.Close.rolling(200).mean()
ma200
# Out:
# Ticker      AAPL
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 3267    152.1331
# 3268    152.0096
# 3269    151.8867
# 3270    151.7593
# 3271    151.6110
#
# [3272 rows x 1 columns]

# %%
plt.figure(figsize = (12,6))
plt.plot(df.Close)
plt.plot(ma100, 'r')
plt.plot(ma200, 'g')

# %%
df.shape
# Out:
# (3272, 5)

# %%
# Splitting data into training and testing
data_training = pd.DataFrame(df['Close'][0:int(len(df) * 0.70)])  # Corrected to use parentheses
data_testing = pd.DataFrame(df['Close'][int(len(df) * 0.70):])  # Corrected slicing to get the remaining data

print(data_training.shape)
print(data_testing.shape)
# Out:
# (2290, 1)
# (982, 1)

# %%
data_training.head()
# Out:
# Ticker      AAPL
# 0       7.643214
# 1       7.656429
# 2       7.534643
# 3       7.520714
# 4       7.570714

# %%
data_testing.head()
# Out:
# Ticker       AAPL
# 2290    42.602501
# 2291    42.357498
# 2292    42.722500
# 2293    42.544998
# 2294    42.700001

# %%
from sklearn.preprocessing import MinMaxScaler
scaler= MinMaxScaler(feature_range=(0,1))

# %%
data_training_array = scaler.fit_transform(data_training)
data_training_array
# Out:
# array([[0.01533047],
#        [0.01558878],
#        [0.01320823],
#        ...,
#        [0.71710501],
#        [0.71739828],
#        [0.70127194]])

# %%
data_training_array.shape
# Out:
# (2290, 1)

# %%
x_train = []
y_train = []

for i in range(100, data_training_array.shape[0]):
    x_train.append(data_training_array[i-100: i])
    y_train.append(data_training_array[i, 0])

x_train, y_train = np.array(x_train), np.array(y_train)

# %%
x_train.shape
# Out:
# (2190, 100, 1)

# %%
#ML model

# %%
# !pip install tensorflow
# !pip install keras
from keras.layers import Dense, Dropout, LSTM 
from keras.models import Sequential

# %%
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(1, 1)))
model.add(Dropout(0.2))
model.add(LSTM(units=50))
model.add(Dropout(0.2))
model.add(Dense(units=1))
# Out:
# C:\Users\sujan\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                          │ (None, 1, 50)               │          10,400 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 1, 50)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 50)                  │          20,200 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 50)                  │               0 │
# ...

# %%
model.compile(optimizer='adam', loss= 'mean_squared_error') 
model.fit(x_train, y_train, epochs=5)
# Out:
# Epoch 1/5
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 14s 98ms/step - loss: 0.0394
# Epoch 2/5
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 7s 99ms/step - loss: 0.0025
# Epoch 3/5
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 10s 93ms/step - loss: 0.0021
# Epoch 4/5
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 11s 97ms/step - loss: 0.0020
# Epoch 5/5
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 7s 96ms/step - loss: 0.0020

# %%
model.save('keras_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
data_testing.head()
# Out:
# Ticker       AAPL
# 2290    42.602501
# 2291    42.357498
# 2292    42.722500
# 2293    42.544998
# 2294    42.700001

# %%
data_training.tail(100)
# Out:
# Ticker       AAPL
# 2190    55.959999
# 2191    54.470001
# 2192    54.560001
# 2193    54.592499
# 2194    55.007500
# ...           ...
# 2285    41.630001
# 2286    42.812500
# 2287    43.544998
# 2288    43.560001
# 2289    42.735001
#
# [100 rows x 1 columns]

# %%
past_100_days = data_training.tail(100)

# %%
final_df = pd.concat([past_100_days, data_testing], ignore_index=True)

# %%
final_df.head()
# Out:
# Ticker       AAPL
# 0       55.959999
# 1       54.470001
# 2       54.560001
# 3       54.592499
# 4       55.007500

# %%
input_data= scaler.fit_transform(final_df)
input_data
# Out:
# array([[0.13937014],
#        [0.1291969 ],
#        [0.1298114 ],
#        ...,
#        [0.61785443],
#        [0.64222927],
#        [0.64441407]])

# %%
input_data.shape
# Out:
# (1082, 1)

# %%
x_test = []
y_test = []
for i in range(100, input_data.shape[0]):
     x_test.append(input_data[i-100: i])
     y_test.append(input_data[i, 0])

# %%
x_test, y_test = np.array(x_test), np.array(y_test)
print(x_test.shape)
print(y_test.shape)
# Out:
# (982, 100, 1)
# (982,)

# %%
#make predictions
y_predicted = model.predict(x_test)
# Out:
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step

# %%
y_predicted.shape
# Out:
# (982, 1)

# %%
y_test
# Out:
# array([0.04816933, 0.04649653, 0.04898865, 0.04777672, 0.04883503,
#        0.04818639, 0.04905691, 0.05093454, 0.04927882, 0.05253905,
#        0.05468976, 0.05486046, 0.05578219, 0.05284628, 0.05595289,
#        0.05745499, 0.05690876, 0.05518478, 0.05173679, 0.05243663,
#        0.06266108, 0.06609201, 0.06745755, 0.07090551, 0.07498506,
#        0.07822822, 0.0756849 , 0.07846719, 0.09029614, 0.08340019,
#        0.07945721, 0.07612869, 0.07899633, 0.07942306, 0.08152257,
#        0.08372451, 0.08846975, 0.09073996, 0.09132031, 0.09355637,
#        0.09884784, 0.09782367, 0.09973542, 0.09688486, 0.09674831,
#        0.0973628 , 0.09739694, 0.10401981, 0.10526585, 0.10640949,
#        0.1114449 , 0.1108987 , 0.10768968, 0.1060169 , 0.10654605,
#        0.09982077, 0.11663396, 0.11429546, 0.11873346, 0.11315182,
#        0.10355893, 0.1036272 , 0.09990612, 0.0938636 , 0.0743023 ,
#        0.07932065, 0.08317828, 0.08174448, 0.079901  , 0.06981308,
# ...

# %%
y_predicted
# Out:
# array([[0.0334476 ],
#        [0.03568849],
#        [0.03754488],
#        [0.03916956],
#        [0.04051764],
#        [0.04166764],
#        [0.04260828],
#        [0.04340567],
#        [0.04415292],
#        [0.0447642 ],
#        [0.04539691],
#        [0.04610788],
#        [0.04684735],
#        [0.0476127 ],
#        [0.04823712],
#        [0.04887237],
#        [0.04955093],
#        [0.05020542],
#        [0.05074195],
#        [0.05102984],
#        [0.0511694 ],
#        [0.05163886],
#        [0.05245356],
#        [0.0535207 ],
#        [0.05485597],
#        [0.05648501],
#        [0.05837647],
#        [0.06025115],
#        [0.06215096],
#        [0.06448907],
#        [0.06672172],
#        [0.06861776],
#        [0.07006418],
#        [0.07127047],
#        [0.07228215],
#        [0.07320986],
#        [0.07413533],
#        [0.07522194],
#        [0.07646543],
#        [0.07778383],
#        [0.07919022],
#        [0.08082022],
#        [0.08248343],
# ...

# %%
scaler.scale_
# Out:
# array([0.00682769])

# %%
scale_factor = 1/0.00682769
y_predicted = y_predicted * scale_factor
y_test = y_test * scale_factor

# %%
# Create a new figure with a specified size of 12 inches wide and 6 inches tall
plt.figure(figsize=(12,6))

# Plot the original price data in blue with a label
plt.plot(y_test, 'b', label = 'Original Price')

# Plot the predicted price data in red with a label
plt.plot(y_predicted, 'r', label = 'Predicted Price')

# Set the label for the x-axis
plt.xlabel('Time')

# Set the label for the y-axis
plt.ylabel('Price')

# Display the legend to differentiate between original and predicted prices
plt.legend()

# Show the plot
plt.show()
